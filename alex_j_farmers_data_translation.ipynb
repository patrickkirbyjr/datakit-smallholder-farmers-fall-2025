# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-jk/datakit-smallholder-farmers-fall-2025/blob/main/alex_j_farmers_data_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clone the repo**

# %%
import os
import pandas as pd
from google.colab import drive

repo_dir = "datakit-smallholder-farmers-fall-2025"

if not os.path.isdir(repo_dir):
    # !git clone https://github.com/alex-jk/datakit-smallholder-farmers-fall-2025.git

# %cd {repo_dir}
# %cd 'Prep Challenge- Translation'
# Out:
# /content/datakit-smallholder-farmers-fall-2025
# /content/datakit-smallholder-farmers-fall-2025/Prep Challenge- Translation

# %% [markdown]
# **Load the farmers survey dataset**

# %%
drive.mount('/content/drive')

export_input_to_parquet = False

# !pip install duckdb -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import duckdb

csv_path = "/content/drive/MyDrive/DataKind Farmers Project/farmers_survey_dataset.csv"
parquet_path = "/content/drive/MyDrive/DataKind Farmers Project/farmers_survey_dataset.parquet"

con = duckdb.connect()

# %%
if export_input_to_parquet:

  con.execute(f"""
      COPY (
          SELECT *
          FROM read_csv_auto('{csv_path}', sample_size=-1)
      )
      TO '{parquet_path}'
      (FORMAT PARQUET);
  """)

# %% [markdown]
# **Connect to the DB**

# %%
parquet_path = "/content/drive/MyDrive/DataKind Farmers Project/farmers_survey_dataset.parquet"

con.execute(f"""
    CREATE OR REPLACE VIEW farmers AS
    SELECT *
    FROM read_parquet('{parquet_path}')
""")

# %%
# Row count
row_count_df = con.execute("SELECT COUNT(*) AS n_rows FROM farmers").df()
n_rows = int(row_count_df.loc[0, "n_rows"])

# Column info
cols_info = con.execute("PRAGMA table_info('farmers')").df()
n_cols = cols_info.shape[0]
col_names = cols_info["name"].tolist()

print(f"DF row count: {n_rows}")
print(f"DF column count: {n_cols}")
print("Column names:")
print(col_names)

# Peek at data
con.execute("SELECT * FROM farmers LIMIT 5").df()
# Out:
# DF row count: 20304843
# DF column count: 24
# Column names:
# ['question_id', 'question_user_id', 'question_language', 'question_content', 'question_topic', 'question_sent', 'response_id', 'response_user_id', 'response_language', 'response_content', 'response_topic', 'response_sent', 'question_user_type', 'question_user_status', 'question_user_country_code', 'question_user_gender', 'question_user_dob', 'question_user_created_at', 'response_user_type', 'response_user_status', 'response_user_country_code', 'response_user_gender', 'response_user_dob', 'response_user_created_at']
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?           None
# 1  Q this goes to wefarm. is it possible to get f...           None
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#               question_sent  response_id  response_user_id response_language  \
# 0 2017-11-22 12:25:03+00:00     20691011            200868               nyn
# 1 2017-11-22 12:25:05+00:00      4334249            526113               eng
# 2 2017-11-22 12:25:08+00:00      3849291            296187               nyn
# 3 2017-11-22 12:25:08+00:00      3849291            296187               nyn
# 4 2017-11-22 12:25:08+00:00      3849291            296187               nyn
#
#                                     response_content  ...  \
# 0                         E!23 Omubazi Ni Dudu Cipa'  ...
# 1          Q1 which stage is marleks last vaccinated  ...
# 2  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
# 3  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
# 4  Muhanguzi.Benon kuruga masha isingiro ente yaw...  ...
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                 None               NaT
# 1                         ug                 None               NaT
# 2                         ug                 None               NaT
# 3                         ug                 None               NaT
# 4                         ug                 None               NaT
#
#    question_user_created_at response_user_type response_user_status  \
# 0 2017-11-18 13:09:11+00:00             farmer                 live
# 1 2017-11-20 11:55:48+00:00             farmer               zombie
# 2 2017-08-22 14:51:07+00:00             farmer               zombie
# 3 2017-08-22 14:51:07+00:00             farmer               zombie
# 4 2017-08-22 14:51:07+00:00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                 None               NaT
# 1                         ug                 None               NaT
# 2                         ug                 None               NaT
# 3                         ug                 None               NaT
# 4                         ug                 None               NaT
#
#    response_user_created_at
# 0 2017-05-09 09:19:33+00:00
# 1 2017-11-22 10:13:03+00:00
# 2 2017-08-12 09:30:33+00:00
# 3 2017-08-12 09:30:33+00:00
# 4 2017-08-12 09:30:33+00:00
#
# [5 rows x 24 columns]

# %% [markdown]
# **Check unique question counts**

# %%
questions_counts = con.execute("""
    SELECT
        question_id,
        question_topic,
        question_content,
        question_language,
        COUNT(*) AS n_responses
    FROM farmers
    GROUP BY
        question_id,
        question_topic,
        question_content,
        question_language
    ORDER BY
        n_responses DESC
""").df()

questions_counts
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#          question_id question_topic  \
# 0           56318162           bean
# 1           58810648          maize
# 2           59076944         tomato
# 3           10326500         tomato
# 4           42820499         cattle
# ...              ...            ...
# 6627404     59256225          plant
# 6627405     59258899          maize
# 6627406     59259045        cabbage
# 6627407     59260982           bird
# 6627408     59261512         tomato
#
#                                           question_content question_language  \
# 0        Q Which hybrid of beans are resistant at this ...               eng
# 1        Q good night ..nataka kuenda kw fam kuchunga m...               swa
# 2        Q If I Tream Tomatoes After harvest can they s...               eng
# 3        E    ekibuzo  enyanya  zange  nazifuyide   egu...               lug
# 4                      QWat are de signs of apregnant cow.               eng
# ...                                                    ...               ...
# 6627404  Q which crop should we plant in this very litt...               eng
# 6627405  Naomba,mbegu ya mahindi..nmeishiwa kabisa na s...               swa
# 6627406  I want to grow cabbage someone to give me the ...               eng
# 6627407  Q how can i permanently control birds destroyi...               eng
# 6627408     Q. Which is the best Season of dlanting tomato               eng
#
#          n_responses
# 0               2984
# 1               2552
# 2               2112
# 3               2043
# 4               2033
# ...              ...
# 6627404            1
# 6627405            1
# 6627406            1
# 6627407            1
# 6627408            1
#
# [6627409 rows x 5 columns]

# %% [markdown]
# **Check if each question ID corresponds to a unique question**

# %%
# All question_ids where there is more than 1 distinct question_content
qid_conflicts = con.execute("""
    SELECT
        question_id,
        COUNT(DISTINCT question_content) AS n_question_contents
    FROM farmers
    GROUP BY question_id
    HAVING COUNT(DISTINCT question_content) > 1
    ORDER BY n_question_contents DESC
""").df()

qid_conflicts
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [question_id, n_question_contents]
# Index: []

# %% [markdown]
# Check english questions and responses

# %%
pd.set_option("display.max_colwidth", None)

qid_counts_by_lang = con.execute("""
    SELECT
        question_language,
        COUNT(DISTINCT question_id) AS n_unique_question_ids
    FROM farmers
    GROUP BY question_language
    ORDER BY question_language
""").df()

qid_counts_by_lang["n_unique_question_ids_fmt"] = (
    qid_counts_by_lang["n_unique_question_ids"].astype(int).map("{:,}".format)
)

display(qid_counts_by_lang)

select_lang = "eng"  # or "swa", "lug", ...

sample_lang = con.execute("""
    SELECT
        question_id,
        question_topic,
        question_content,
        response_content,
        question_language
    FROM farmers
    WHERE question_language = ?
      AND question_content IS NOT NULL
      AND response_content IS NOT NULL
    ORDER BY random()
    LIMIT 20
""", [select_lang]).df()

print(f"\n-------Questions Sample {select_lang}------\n")
display(sample_lang)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#   question_language  n_unique_question_ids n_unique_question_ids_fmt
# 0               eng                2940542                 2,940,542
# 1               lug                 265958                   265,958
# 2               nyn                 433345                   433,345
# 3               swa                2225974                 2,225,974
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# -------Questions Sample eng------
#     question_id question_topic  \
# 0      46918495          maize
# 1      23520242        chicken
# 2      12589015         cattle
# 3       3913570         tomato
# 4      13306274          maize
# 5      15305545          wheat
# 6      15893341         rabbit
# 7      30823411         potato
# 8      22130725         potato
# 9      27091716         rabbit
# 10     13439662          maize
# 11     45456676            pig
# 12     38922065           bean
# 13      3977319            pig
# 14     25193351          plant
# 15     46128250         cattle
# 16     30046820           None
# 17     29339267          sheep
# 18     53187714            pig
# 19     14666735           None
#
#                                                                                                                              question_content  \
# 0   Theophilus asks: What s the easiest way to prevent squirrels from digging out young maize seedlings? Reply Q34 followed by your response.
# 1                                                                      Q how long does a layers take from one day to producing the first egg.
# 2                                                             Q which medicine can i give a calf of one yr old who as been weak about 3months
# 3                                                                                             Q:how can mtu know that the bull wants to mate?
# 4                                                                      Q What makes our maize not to grow tall and are eaten with some dudus?
# 5                                                                                                                        e what is livestock?
# 6                                                                           Which type of medicine do we use when I want to deworm the rabbit
# 7                                                                                             which is the best soil to plant shangi potatoes
# 8                                                                   Q What disease attack irish potato and wat is name ov dat germ? Tell Guys
# 9                                                                           Q: WHAT ARE THE BEST FEEDS FOR RABIT AND WHAT IS THE MARKET PRICE
# 10                                                                                What is the name given to the flowering part of maize crop?
# 11                                                                                                      E what is the sweetest food for pigs?
# 12                                                                                (Q)What is real spacing  of 1maize 2beans 3potatoes 4peans?
# 13                                                                                                             Where Can I Get Gravalia Seeds
# 14                                                    Q How do I plant Napier grass that lasts long within a limited space and which variety?
# 15                                                                                          My cow is incalf 8 months which salt shall i use?
# 16              Q I use sawdust on the floor of chikens' house but the problem is that dudus lyk very much n it disturbs a lot, what do I do?
# 17                                                                               Q i evident a roughcout on my sheep what could be the cause?
# 18                                                                                 What makes my pigs to fail to become pregnant yet it mates
# 19                                                      Q which part does scania,lethal, smut,blosom,army worms and stunted growth do affects
#
#                                                                                                                                                                                                                                                                         response_content  \
# 0                                                                                                                                                                                                                                                     Q.981 mix some maize with seedling
# 1                                                                                                                                                                                                                                                                 Q159 btn 3 to 4 months
# 2                                                                                                                                                                                                                                                                               Q deworm
# 3                                                                                                                                                                                                                                   Q33wen it is near the cow it starts climbing the cow
# 4                                                                                                                                                                                                            Q4 not applying fertilisers or enough fertilisers to the maize, not weeding
# 5                                                                                                                                                                                                                                                Q172 LIVESTOCK IS ALL KINDS OF ANIMALS.
# 6                                                                                                                                                                                                                                                                          Q23 phalvacen
# 7                                                                                                                                                                                                                 Q69 USE RED VOLCANIC SOIL FOUND IN THE HIGHLANDS LIKE NYANDARUA COUNTY
# 8                                                                                                                                                                                                   Q32 Same types like enemies of g nuts use same treatment of tomatoes, cabbages, etc.
# 9   Q75\nBest foods for rabbits are the simple garden produce. Cabbages, carrots, kale, spinach, cucumber, sweet potatoes, lettuce, are just to mention a few among the best foods for rabbits on top of others like tomato and potato  leaves.\nCheck the prices at ayour local market.
# 10                                                                                                                                                                                                                                      Q360 Fillament:its the male part of maize plant.
# 11                                                                                                                                                                                                                                                      Q517,it is stem tuber of the yam
# 12                                                                                                                                                                                                           Q237. For maize 45cm by 30cm,beans 30cm by 20cm, 45cm by 15cm, 30cm by 30cm
# 13                                                                                                                                                                                                                               Q19:just join One Acre Fund and will be given the seeds
# 14                                                                                                                                                                                                                                                                          Q 35 pasture
# 15                                                                                                                                                                                                                                          Q5 ask vet which recommendable for a dry cow
# 16                                                                                                                                                                                                                         Q9 Remove The Sowdust and Spray using DUDU_KRIN Then Put Sand
# 17                                                                                                                                                                                                                                                                        Q718 I DONT NO
# 18                                                                                                                                                                                                                                                Q327: most times its lack of treatment
# 19                                                                                                                                                                                                                                                                               Q2 stem
#
#    question_language
# 0                eng
# 1                eng
# 2                eng
# 3                eng
# 4                eng
# 5                eng
# 6                eng
# 7                eng
# 8                eng
# 9                eng
# 10               eng
# 11               eng
# 12               eng
# 13               eng
# 14               eng
# 15               eng
# 16               eng
# 17               eng
# 18               eng
# 19               eng
